# %%
import asyncio
from chatbot import get_response
from goku_voice import speak_and_save, play_audio

# %%
user_input = "Hey Goku, how's your training going?"
reply = get_response(user_input)
print(reply)

await speak_and_save(reply)  # Generate voice file
play_audio()                 # Play voice
# Out:
# Goku:  Goku:  Goku: Alright, training's going just swell! I've been keeping up with my workouts and sparring with friends. I'm always on the lookout for a good challenge. Whoa, you're strong! Let's spar! I'm hungry... I wonder if Bulma has cooked up something tasty for me to eat afterwards. That would be awesome!
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
